# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import cv2 as cv 
import matplotlib.pyplot as plt

# %%
image1 = cv.imread('Coins.png')

# %%
if image1 is None:
    raise FileNotFoundError("Không tìm thấy file.")
plt.imshow(image1)
plt.show()

# %%
image1_gray = cv.cvtColor(image1, cv.COLOR_BGR2GRAY)
plt.imshow(image1_gray)

# %%
image1_RGB = cv.cvtColor(image1, cv.COLOR_BGR2RGB)
plt.imshow(image1_RGB)

# %%
image1_blur = cv.
